# %%
import numpy as np 
import tensorflow as tf 
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import SimpleRNN, Dense 
from sklearn.metrics import r2_score

# %%
np.random.seed(0) 
seq_length = 10 
num_samples = 1000

# %%
X = np.random.randn(num_samples, seq_length, 1) 
y = X.sum(axis=1) + 0.1 * np.random.randn(num_samples, 1)

# %%
split_ratio = 0.8 
split_index = int(split_ratio * num_samples)

# %%
X_train, X_test = X[:split_index], X[split_index:] 
y_train, y_test = y[:split_index], y[split_index:]

# %%
model = Sequential() 
model.add(SimpleRNN(units=50, activation='relu', input_shape=(seq_length, 1))) 
model.add(Dense(units=1))

# %%
model.compile(optimizer='adam', loss='mean_squared_error') 
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 50)                2600
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 2,651
# Trainable params: 2,651
# Non-trainable params: 0
# _________________________________________________________________

# %%
batch_size = 30 
epochs = 50 # Reduced epochs for quick demonstration

# %%
history = model.fit( 
 X_train, y_train, 
 batch_size=batch_size,
 epochs=epochs, 
 validation_split=0.2 
)
# Out:
# Epoch 1/50
# 22/22 [==============================] - 2s 23ms/step - loss: 8.7454 - val_loss: 6.3263
# Epoch 2/50
# 22/22 [==============================] - 0s 4ms/step - loss: 5.8837 - val_loss: 3.7798
# Epoch 3/50
# 22/22 [==============================] - 0s 5ms/step - loss: 3.7728 - val_loss: 2.3105
# Epoch 4/50
# 22/22 [==============================] - 0s 5ms/step - loss: 1.7141 - val_loss: 0.5373
# Epoch 5/50
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2878 - val_loss: 0.2417
# Epoch 6/50
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1304 - val_loss: 0.1146
# Epoch 7/50
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1111 - val_loss: 0.1303
# Epoch 8/50
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0962 - val_loss: 0.0683
# Epoch 9/50
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0582 - val_loss: 0.0543
# Epoch 10/50
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0468 - val_loss: 0.0383
# Epoch 11/50
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0374 - val_loss: 0.0338
# Epoch 12/50
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0337 - val_loss: 0.0402
# Epoch 13/50
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0299 - val_loss: 0.0327
# Epoch 14/50
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0265 - val_loss: 0.0397
# Epoch 15/50
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0270 - val_loss: 0.0270
# Epoch 16/50
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0232 - val_loss: 0.0272
# Epoch 17/50
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0237 - val_loss: 0.0246
# Epoch 18/50
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0234 - val_loss: 0.0321
# Epoch 19/50
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0223 - val_loss: 0.0248
# Epoch 20/50
# 22/22 [==============================] - 0s 8ms/step - loss: 0.0242 - val_loss: 0.0305
# Epoch 21/50
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0261 - val_loss: 0.0367
# Epoch 22/50
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0325 - val_loss: 0.0298
# Epoch 23/50
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0240 - val_loss: 0.0272
# Epoch 24/50
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0205 - val_loss: 0.0217
# Epoch 25/50
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0196 - val_loss: 0.0264
# Epoch 26/50
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0202 - val_loss: 0.0237
# Epoch 27/50
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0283 - val_loss: 0.0289
# Epoch 28/50
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0198 - val_loss: 0.0209
# Epoch 29/50
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0174 - val_loss: 0.0255
# Epoch 30/50
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0174 - val_loss: 0.0220
# Epoch 31/50
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0156 - val_loss: 0.0196
# Epoch 32/50
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0182 - val_loss: 0.0286
# Epoch 33/50
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0222 - val_loss: 0.0256
# Epoch 34/50
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0145 - val_loss: 0.0194
# Epoch 35/50
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0150 - val_loss: 0.0210
# Epoch 36/50
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0160 - val_loss: 0.0188
# Epoch 37/50
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0141 - val_loss: 0.0226
# Epoch 38/50
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0159 - val_loss: 0.0216
# Epoch 39/50
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0141 - val_loss: 0.0198
# Epoch 40/50
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0178 - val_loss: 0.0194
# Epoch 41/50
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0180 - val_loss: 0.0267
# Epoch 42/50
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0132 - val_loss: 0.0194
# Epoch 43/50
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0163 - val_loss: 0.0354
# Epoch 44/50
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0159 - val_loss: 0.0182
# Epoch 45/50
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0140 - val_loss: 0.0369
# Epoch 46/50
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0292 - val_loss: 0.0416
# Epoch 47/50
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0176 - val_loss: 0.0290
# Epoch 48/50
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0162 - val_loss: 0.0251
# Epoch 49/50
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0261 - val_loss: 0.0434
# Epoch 50/50
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0269 - val_loss: 0.0199

# %%
test_loss = model.evaluate(X_test, y_test) 
print(f'Test Loss: {test_loss:.4f}')
# Out:
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0201
# Test Loss: 0.0201

# %%
y_pred = model.predict(X_test) 
r2 = r2_score(y_test, y_pred) 
print(f'Test Accuracy (R^2): {r2:.4f}')
# Out:
# 7/7 [==============================] - 0s 2ms/step
# Test Accuracy (R^2): 0.9978

# %%
new_data = np.random.randn(5, seq_length, 1)
predictions = model.predict(new_data)
print("Predictions for new data:") 
print(predictions)
# Out:
# 1/1 [==============================] - 0s 20ms/step
# Predictions for new data:
# [[ 1.5437698]
#  [ 0.4290885]
#  [-2.1180325]
#  [-0.5443404]
#  [-3.8416493]]
